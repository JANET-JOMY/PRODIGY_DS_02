# %% [markdown]
# # Task 02
# To perform data cleaning and EDA  on a dataset of your choice.explore the relationship between variables and identify patterns and trends in the data.
#
# Dataset:Car data set
# Source:Kaggle

# %%
#load domain dataset
import pandas as pd
df=pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.head(10)
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 0              Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2       Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3     Datsun RediGO T Option  2017         250000      46000  Petrol
# 4      Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5       Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6  Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7   Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8   Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9   Maruti Celerio Green VXI  2017         365000      78000     CNG
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# ...

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
print("print info")
df.info()
# Out:
# print info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %%
print("\nmissimg values:")
print(df.isnull().sum())
# Out:
# missimg values:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
#finding the car which have covered the maximum distance
max_distance_index = df['km_driven'].idxmax()
car_with_max_distance = df.loc[max_distance_index]
print("Car with Maximum Distance Covered:")
print(car_with_max_distance)
# Out:
# Car with Maximum Distance Covered:
# name             Maruti Swift VXI BSIII
# year                               2009
# selling_price                    250000
# km_driven                        806599
# fuel                             Petrol
# seller_type                      Dealer
# transmission                     Manual
# owner                       First Owner
# Name: 1243, dtype: object

# %%
#car with maximum selling price
max_sellingprice = df['selling_price'].idxmax()
car_with_max_sellingprice = df.loc[max_sellingprice]
print("Car with Maximum selling price:")
print(car_with_max_sellingprice)
# Out:
# Car with Maximum selling price:
# name             Audi RS7 2015-2019 Sportback Performance
# year                                                 2016
# selling_price                                     8900000
# km_driven                                           13000
# fuel                                               Petrol
# seller_type                                        Dealer
# transmission                                    Automatic
# owner                                         First Owner
# Name: 3872, dtype: object

# %%
df["name_2"] = df.name.apply(lambda x : ' '.join(x.split(' ')[:1]))
df['name_2']
# Out:
# 0        Maruti
# 1        Maruti
# 2       Hyundai
# 3        Datsun
# 4         Honda
#          ...
# 4335    Hyundai
# 4336    Hyundai
# 4337     Maruti
# 4338    Hyundai
# 4339    Renault
# Name: name_2, Length: 4340, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=df,x="name_2",palette="CMRmap")
plt.xticks(rotation=90)
plt.xlabel("Name",fontsize=10,color="blue")
plt.ylabel("Name",fontsize=10,color="blue")
plt.title("NAME COUNT",color="blue")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt  
import pandas as pd 
sns.countplot(x='fuel',hue='transmission',data=df)
plt.title('Types of fuel and transmission data')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='seller_type', data=df)
plt.title('Count of Cars by Seller Type')
plt.xlabel('Seller Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='transmission', data=df)
plt.title('Count of Cars by Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='owner', data=df)
plt.title('Count of Cars by Owner Type')
plt.xlabel('Owner Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.subplot(2, 2, 1)
sns.histplot(df['selling_price'], kde=True)
plt.title('Distribution of Selling Price')

plt.subplot(2, 2, 2)
sns.histplot(df['km_driven'], kde=True)
plt.title('Distribution of Kilometers Driven')
# Out:
# Text(0.5, 1.0, 'Distribution of Kilometers Driven')

# %%
labels = df["year"][:40].value_counts().index
sizes = df["year"][:40].value_counts()
colors = ['#ff9999','#66b3ff','#99ff89','#ffcc99',"red","yellow"]
plt.figure(figsize = (6,8))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%',colors=colors,shadow=True, startangle=45)
plt.title('Year',color = 'red',fontsize = 15)
plt.show()

# %%
sns.countplot(data=df,x="year",palette="icefire")
plt.xticks(rotation=90)
plt.xlabel("YEAR",fontsize=10,color="black")
plt.ylabel("COUNT",fontsize=10,color="RED")
plt.title("YEAR COUNT",color="blue")
plt.show()

# %%
plt.figure(figsize=(15, 8))

plt.subplot(2, 2, 3)
sns.countplot(x='fuel', data=df)
plt.title('Count of Cars by Fuel Type')

plt.subplot(2, 2, 4)
sns.countplot(x='owner', data=df)
plt.title('Count of Cars by Owner Type')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='selling_price', y='km_driven', data=df)
plt.title('Selling Price vs Kilometers Driven')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='fuel', y='selling_price', data=df)
plt.title('Distribution of Selling Price by Fuel Type')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='fuel', y='selling_price', data=df)
plt.title('Distribution of Selling Price by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Selling Price')
plt.show()

# %%
sns.violinplot(data=df, x="year", y="fuel",hue="transmission")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='year', y='selling_price', data=df)
plt.title('Trend of Selling Price Over Year')
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.show()

# %%
# Correlation matrix
correlation_matrix = df[['selling_price', 'km_driven', 'year']].corr()

# Heatmap of correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Ridgeline plot of selling_price by fuel type
plt.figure(figsize=(15, 6))
sns.kdeplot(data=df, x='selling_price', hue='fuel', fill=True)
plt.title('Ridgeline Plot of Selling Price by Fuel Type')
plt.xlabel('Selling Price')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29356\1839779498.py:3: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df, x='selling_price', hue='fuel', fill=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation matrix
correlation_matrix = df[['selling_price', 'km_driven', 'year']].corr()

# Correlogram
sns.pairplot(df[['selling_price', 'km_driven', 'year']])
plt.suptitle('Correlogram', y=1.02)
plt.figure(figsize=(15, 6))
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Inference
# A Car dataset was considered, and since it has no null values, cleaning of data wasn't required here.
# After performing EDA(Exploratory Data Analysis),the relationships between variables, patterns and trends in the data were identified.
#
# The analysis shows that  "Maruti Swift VXI BSIII(2009 model)" has covered the maximum distance of "806599 km", and "Audi RS7 2015-2019 Sportback Performance" is the car with maximum selling price of 8900000.
#
# It was found:
# Cars with fuel type "petrol" has high rate of transmission : "manual".
# The pie chart indicates that most of the cars are manufactured in the year 2017.
# The best selling car is the Maruti. Next comes Hyundai.
# Cars are usually manual.
# We can say that vehicles are generally sold first-hand, followed by second-hand vehicles.
# Most of the sales are made individually.
# There are very few outliers in the data.
# Line plot indicates that selling price is increasing as years increase.
